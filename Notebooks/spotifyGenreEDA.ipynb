# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import pickle

# %% [markdown]
# ## **Part 1:** Loading the Data

# %%
#Read in Data 
spotify_df = pd.read_pickle('../Data/spotify_df.pkl')

# %%
spotify_df.head()
# Out:
#                                   track_id          artist  \
# The Sound of Pop 0  27ycaQnQAxaPiyeg3nr2aB     Miley Cyrus
#                  1  0prNGof3XqfTvNDxHonvdK    Alessia Cara
#                  2  3e7sxremeOE3wTySiOhGiP            ZAYN
#                  3  4l0Mvzj72xxOpRrp6h8nHi    Selena Gomez
#                  4  1rfofaqEpACxVEHIZBJe6W  Camila Cabello
#
#                                  artist_id                 album  \
# The Sound of Pop 0  5YGY8feqx7naU7z4HrwZM6          Midnight Sky
#                  1  2wUjUUtkb5lvLKcGKsKqsR  Know-It-All (Deluxe)
#                  2  5ZsFI1h6hIdQRw2ti0hz81          Icarus Falls
#                  3  0C8ZW7ezQVs4URX5aX7Kqx                  Rare
#                  4  4nDoRrQiYLoBzwC5BhVJzF                Camila
#
#                                                   trackName  acousticness  \
# The Sound of Pop 0                             Midnight Sky       0.00115
# ...

# %% [markdown]
# ## **Part 2:** Overview of the Spotify Dataset
#
#  - What are the Columns of the Dataset

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 10901 entries, ('The Sound of Pop', 0) to ('The Sound of Jazz', 397)
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          10901 non-null  object
#  1   artist            10901 non-null  object
#  2   artist_id         10901 non-null  object
#  3   album             10901 non-null  object
#  4   trackName         10901 non-null  object
#  5   acousticness      10901 non-null  float64
#  6   danceability      10901 non-null  float64
#  7   duration_ms       10901 non-null  int64
#  8   energy            10901 non-null  float64
#  9   instrumentalness  10901 non-null  float64
#  10  key               10901 non-null  int64
#  11  liveness          10901 non-null  float64
#  12  loudness          10901 non-null  float64
#  13  mode              10901 non-null  int64
#  14  speechiness       10901 non-null  float64
# ...

# %%
spotify_df.describe()
# Out:
#        acousticness  danceability    duration_ms        energy  \
# count  10901.000000  10901.000000   10901.000000  10901.000000
# mean       0.185651      0.588397  235613.177323      0.687171
# std        0.253967      0.170879   66422.383405      0.206597
# min        0.000000      0.061700  120133.000000      0.005900
# 25%        0.008150      0.474000  193093.000000      0.558000
# 50%        0.064300      0.597000  222733.000000      0.716000
# 75%        0.260000      0.713000  263867.000000      0.854000
# max        0.996000      0.979000  599560.000000      1.000000
#
#        instrumentalness           key      liveness      loudness  \
# count      10901.000000  10901.000000  10901.000000  10901.000000
# mean           0.088659      5.249610      0.188820     -7.219767
# std            0.219831      3.577168      0.147073      3.458108
# min            0.000000      0.000000      0.013500    -29.949000
# ...

# %% [markdown]
# ### Answering Questions About the Dataset

# %%
# What (and how many) Genres are in this dataset 
genre_list = ['pop','dance_pop','rap','rock','hip_hop','country','edm','indie_pop','indie_rock','punk','metal',
              'alternative_rock','jazz']
len(genre_list)
# Out:
# 13

# %%
# How many unique tracks?
spotify_df.track_id.nunique()
# Out:
# 8528

# %%
# How many tracks per genre 
spotify_df.category_id.value_counts()
# Out:
# dance_pop           1220
# rock                1208
# pop                 1094
# edm                  993
# hip_hop              974
# rap                  927
# indie_rock           927
# indie_folk           738
# alternative_rock     686
# metal                620
# country              578
# punk                 538
# jazz                 398
# Name: category_id, dtype: int64

# %%
# What Artists show up in multiple genres within the dataset
spotify_df.groupby('category_id')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-54ddb0ebbaa5> in <module>
#       1 # What Artists show up in multiple genres within the dataset
# ----> 2 spotify_df.groupby('category_id').duplicated(['artist','artist_id'])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     578             return self[attr]
#     579
# --> 580         raise AttributeError(
#     581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'duplicated'

# %% [markdown]
# ####  Key Observations
#
#
#  - Not all genres have the same number of tracks, could affect any classifier if this not taken into account when building the training and test data sets
#  - There are some songs that show up in multiple genres, this could be interesting to test how a classifier handles these tracks

# %%
# How many unique artist?
spotify_df.artist.nunique()
# Out:
# 4066

# %%
#What artists has the most tracks in the dataset?
spotify_df.artist.value_counts()[:50]
# Out:
# Various Artists             109
# Spoon                        11
# The Replacements             10
# Pavement                     10
# Silversun Pickups            10
# Modest Mouse                  9
# Cheat Codes                   9
# Jax Jones                     9
# Zedd                          9
# The Stooges                   9
# Deerhunter                    9
# The Magnetic Fields           9
# TV On The Radio               9
# B.o.B                         9
# Wilco                         9
# Miles Davis                   9
# Sigala                        9
# T-Pain                        9
# The Shins                     9
# Built To Spill                9
# The Flaming Lips              9
# Yeah Yeah Yeahs               9
# Axwell /\ Ingrosso            8
# Galantis                      8
# of Montreal                   8
# Neutral Milk Hotel            8
# Matoma                        8
# Cold War Kids                 8
# Galaxie 500                   8
# ...

# %%
# What track titles are the most frequent in the dataset?
spotify_df.trackName.value_counts()[:15]
# Out:
# Friends         9
# Inside Out      7
# Fire            7
# Wake Up         7
# Boyfriend       6
# Heaven          6
# You             6
# Nobody          6
# Alive           6
# Smile           6
# Dreams          6
# 17              5
# Stay            5
# Poison          5
# Wolf Like Me    5
# Name: trackName, dtype: int64

# %%
# What are the mean values of each genre
spotify_df.groupby('category_id').mean()
# Out:
#                   acousticness  danceability    duration_ms    energy  \
# category_id
# alternative_rock      0.134125      0.479895  249632.240525  0.719192
# country               0.281809      0.594408  212530.653979  0.621906
# dance_pop             0.149903      0.673761  220532.972951  0.701839
# edm                   0.072751      0.625912  213045.158107  0.805631
# hip_hop               0.146842      0.746474  244850.650924  0.674049
# indie_folk            0.292841      0.556757  224417.537940  0.605993
# indie_rock            0.238715      0.505879  245142.484358  0.658068
# jazz                  0.794667      0.507399  329912.992462  0.292020
# metal                 0.018345      0.379360  284769.953226  0.870713
# pop                   0.255723      0.648892  208186.843693  0.618765
# punk                  0.049300      0.419628  192301.659851  0.872485
# rap                   0.134690      0.760892  233219.533981  0.652259
# ...

# %% [markdown]
# #### Key Observations
#
#  - Pop is the most popular genre, followed by Rap and dance pop
#  - Rap and Hip Hop are the most danceable genres, and Metal is the least
